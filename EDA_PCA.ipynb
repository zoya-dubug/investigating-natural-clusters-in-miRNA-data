# %%
#Libraries and Modules
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
plt.style.use("default")

# %%
#Load Dataset
df = pd.read_csv("tissue_dataset.csv")

df.shape
# Out:
# (133, 1928)

# %%
#Basic Exploration
df.info()

df.head()

print(df.columns[:5])
print(df.columns[-5:])

print(
    "Missing Values:",
    df.isnull().sum().sum()
)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Columns: 1928 entries, 4040 : hsa-miR-9-5p to target_actual
# dtypes: float64(1926), int64(1), str(1)
# memory usage: 2.0 MB
# Index(['4040 : hsa-miR-9-5p', '4610 : hsa-miR-126-3p', '4700 : hsa-miR-140-5p',
#        '5250 : hsa-miR-105-5p', '6880 : hsa-miR-297'],
#       dtype='str')
# Index(['169417 : hsa-miR-551b-5p', '169419 : hsa-miR-300',
#        '169420 : hsa-miR-193b-5p', 'target', 'target_actual'],
#       dtype='str')
# Missing Values: 0

# %%
#Class Dsitribution
df["target_actual"].value_counts()
# Out:
# target_actual
# primary breast cancer    122
# normal breast tissue      11
# Name: count, dtype: int64

# %%
#Class Distribution plot
plt.figure(figsize=(8,5))

df["target_actual"].value_counts().plot(
    kind="bar"
)

plt.title("Class Distribution")
plt.xticks(rotation = 0)
plt.ylabel("Count")
plt.savefig(
    "screenshots/Class Distribution plot",
    dpi=300,
    bbox_inches="tight"
)
plt.show()

# %%
#Feature seperation
y = df["target_actual"]
X = df.drop(columns = ["target", "target_actual"])

# %%
#Scaling
std_scal = StandardScaler()
X_scaled = std_scal.fit_transform(X)

# %%
#PCA
pca_full = PCA()

pca_full.fit(X_scaled)
# Out:
# PCA()

# %%
EVR = pca_full.explained_variance_ratio_

CVR = np.cumsum(EVR)

components_90 = np.argmax(CVR >= 0.90) + 1

print(components_90)
# Out:
# 32

# %%
#Final PCA
pca = PCA(n_components=32)

PC = pca.fit_transform(X_scaled)

# %%
#PCA Dataframe
columns = [
    f"PC{i}"
    for i in range(1,33)
]

df_pca = pd.DataFrame(
    PC,
    columns=columns
)
df_pca["target_actual"] = y

# %%
#PCA Visualization
sns.scatterplot(
    data=df_pca,
    x="PC1",
    y="PC2",
    hue="target_actual"
)
plt.savefig(
    "screenshots/PCA scatter plot (PC1 vs PC2)",
    dpi=300,
    bbox_inches="tight"
)

# %%
df_pca.to_csv(
    "pca_dataset.csv",
    index=False
)
